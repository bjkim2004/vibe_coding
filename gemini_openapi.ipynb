# %%
# Import the Python SDK
import google.generativeai as genai
# Used to securely store your API key
from google.colab import userdata

genai.configure(api_key='AIzaSyBVkjxopnpae24riDF4NlU3PijewTbLBxM')

# %%
# https://ai.google.dev/gemini-api/docs/rate-limits?hl=ko#free-tier

# %%
for m in genai.list_models():
  if 'generateContent' in m.supported_generation_methods:
    print(m.name)
# Out:
# models/gemini-2.5-pro-preview-03-25
# models/gemini-2.5-flash-preview-05-20
# models/gemini-2.5-flash
# models/gemini-2.5-flash-lite-preview-06-17
# models/gemini-2.5-pro-preview-05-06
# models/gemini-2.5-pro-preview-06-05
# models/gemini-2.5-pro
# models/gemini-2.0-flash-exp
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-exp-image-generation
# models/gemini-2.0-flash-lite-001
# models/gemini-2.0-flash-lite
# models/gemini-2.0-flash-preview-image-generation
# models/gemini-2.0-flash-lite-preview-02-05
# models/gemini-2.0-flash-lite-preview
# models/gemini-2.0-pro-exp
# models/gemini-2.0-pro-exp-02-05
# models/gemini-exp-1206
# models/gemini-2.0-flash-thinking-exp-01-21
# models/gemini-2.0-flash-thinking-exp
# models/gemini-2.0-flash-thinking-exp-1219
# models/gemini-2.5-flash-preview-tts
# models/gemini-2.5-pro-preview-tts
# models/learnlm-2.0-flash-experimental
# models/gemma-3-1b-it
# models/gemma-3-4b-it
# models/gemma-3-12b-it
# models/gemma-3-27b-it
# models/gemma-3n-e4b-it
# models/gemma-3n-e2b-it
# models/gemini-flash-latest
# models/gemini-flash-lite-latest
# models/gemini-pro-latest
# models/gemini-2.5-flash-lite
# models/gemini-2.5-flash-image-preview
# models/gemini-2.5-flash-image
# models/gemini-2.5-flash-preview-09-2025
# models/gemini-2.5-flash-lite-preview-09-2025
# models/gemini-robotics-er-1.5-preview
# models/gemini-2.5-computer-use-preview-10-2025

# %%
gemini_model = genai.GenerativeModel('models/gemini-2.0-flash')

# %%
response = gemini_model.generate_content('최근 생성형 AI 트렌드 알려줘')
print(response.text)
# Out:
# 최근 생성형 AI 트렌드는 매우 빠르게 변화하고 있으며, 다양한 분야에서 혁신적인 발전을 보여주고 있습니다. 주요 트렌드를 다음과 같이 정리해 드릴 수 있습니다.
#
# **1. 멀티모달 AI의 발전:**
#
# *   **텍스트-이미지, 이미지-텍스트 넘어 오디오, 비디오 통합:** 단순히 텍스트와 이미지를 생성하는 것을 넘어, 오디오, 비디오까지 이해하고 생성하는 멀티모달 AI가 더욱 발전하고 있습니다. 예를 들어, 텍스트 설명을 기반으로 비디오를 생성하거나, 반대로 비디오 내용을 분석하여 텍스트 설명을 생성하는 것이 가능해졌습니다.
# *   **실생활 응용 확대:** 멀티모달 AI는 교육, 엔터테인먼트, 광고 등 다양한 분야에서 활용되고 있으며, 특히 시각 및 청각 장애인을 위한 접근성 향상에 기여할 것으로 기대됩니다.
#
# **2. 생성형 AI의 창의성 및 제어 가능성 향상:**
#
# *   **스타일 일관성 및 제어 강화:** 생성된 콘텐츠의 스타일을 일관되게 유지하고, 사용자가 원하는 특정 스타일을 적용하는 기능이 향상되고 있습니다. 이는 브랜드 아이덴티티를 유지하거나 특정 예술적 스타일을 모방하는 데 유용합니다.
# *   **미세 조정(Fine-tuning) 및 개인화:** 사용자의 특정 요구사항이나 선호도에 맞춰 모델을 미세 조정하여 더욱 개인화된 콘텐츠를 생성하는 기술이 발전하고 있습니다.
#
# **3. 특정 산업 분야에 특화된 생성형 AI:**
#
# *   **의료, 금융, 법률 등 전문 분야 맞춤형 AI:** 특정 산업 분야의 전문 지식을 학습한 생성형 AI 모델이 등장하고 있습니다. 이러한 모델은 해당 분야의 전문 용어를 이해하고, 복잡한 문제를 해결하는 데 도움을 줄 수 있습니다.
# *   **데이터 보안 및 규제 준수 중요성 증가:** 전문 분야에 특화된 AI 모델은 민감한 데이터를 다루는 경우가 많으므로, 데이터 보안 및 규제 준수가 더욱 중요해지고 있습니다.
#
# **4. AI 에이전트 및 자율 시스템:**
#
# *   **자율적인 의사 결정 및 행동:** 생성형 AI를 기반으로 사용자의 목표를 이해하고, 자율적으로 작업을 수행하는 AI 에이전트가 개발되고 있습니다.
# *   **자동화 및 생산성 향상:** AI 에이전트는 복잡한 작업을 자동화하고, 사용자의 생산성을 향상시키는 데 기여할 수 있습니다.
#
# **5. 윤리적 문제 및 책임감 있는 AI 개발:**
#
# *   **가짜 정보 생성 및 확산 방지:** 생성형 AI가 생성하는 가짜 정보(deepfake)의 확산을 방지하기 위한 기술적, 정책적 노력이 강화되고 있습니다.
# *   **저작권 및 지적 재산권 보호:** 생성형 AI가 생성한 콘텐츠의 저작권 및 지적 재산권 관련 문제가 중요한 이슈로 떠오르고 있으며, 이에 대한 논의가 활발하게 진행되고 있습니다.
# *   **AI 윤리 교육 및 거버넌스 강화:** AI 개발자와 사용자를 위한 윤리 교육이 강화되고 있으며, AI 거버넌스 체계를 구축하려는 노력이 이루어지고 있습니다.
#
# **6. AI 모델 경량화 및 효율성 증대:**
#
# *   **온디바이스 AI:** 클라우드 서버에 의존하지 않고, 스마트폰, 노트북 등 기기 자체에서 AI 모델을 실행하는 온디바이스 AI 기술이 발전하고 있습니다.
# *   **에너지 효율성 향상:** AI 모델의 크기를 줄이고, 연산 효율성을 높여 에너지 소비를 줄이는 기술이 중요해지고 있습니다.
#
# **7. 오픈소스 AI 생태계 확장:**
#
# *   **오픈소스 모델 및 도구 공개:** 누구나 자유롭게 사용할 수 있는 오픈소스 AI 모델 및 도구가 많이 공개되면서, AI 기술 개발 및 활용이 더욱 가속화되고 있습니다.
# *   **커뮤니티 참여 및 협업 활성화:** 오픈소스 AI 커뮤니티를 중심으로 기술 공유 및 협업이 활발하게 이루어지고 있습니다.
#
# 이 외에도 생성형 AI 기술은 끊임없이 발전하고 있으며, 앞으로 우리 사회에 더 큰 영향을 미칠 것으로 예상됩니다. 이러한 트렌드를 지속적으로 주시하고, 자신의 분야에 어떻게 적용할 수 있을지 고민하는 것이 중요합니다.
#
# 좀 더 구체적인 정보나 특정 분야에 대한 트렌드를 알고 싶으시다면, 질문을 더 자세하게 해주세요. 예를 들어, "최근 이미지 생성 AI 모델의 성능 비교" 또는 "생성형 AI를 활용한 마케팅 전략 트렌드"와 같이 질문해주시면 더욱 정확한 답변을 드릴 수 있습니다.
